# %%
import pandas as pd 

df = pd.read_csv('employees.csv')
df
# Out:
#        Name  Age  Gender Department  Salary              Email       Phone  \
# 0     GMKEU   55    Male  Marketing   70467  gmkeu@company.com   996823412
# 1     JNTVL   59  Female         IT   42577  jntvl@company.com  2254598094
# 2     LXJJN   32  Female    Finance   44144  lxjjn@company.com   495419292
# 3     AAOJG   27    Male    Finance   43716  aaojg@company.com  4821466300
# 4     ENLRK   52    Male    Finance   52023  enlrk@company.com  8468707446
# ...     ...  ...     ...        ...     ...                ...         ...
# 9995  HYCXD   48    Male  Marketing   53155  hycxd@company.com  8632088627
# 9996  HHYED   27    Male      Sales   45778  hhyed@company.com  8851351162
# 9997  GPIIQ   32  Female      Sales   51703  gpiiq@company.com  1295582939
# 9998  JCZWF   57  Female  Marketing   75841  jczwf@company.com  4355910372
# 9999  GCITK   31    Male         IT   74754  gcitk@company.com  4277298867
#
#          Address      City State Country  Postal Code
# 0     WXEYPH2J6H  New York    TX     USA        69962
# 1     04D17EMNKA     Paris    CA  France        12950
# 2     76V13L6M83     Paris    CA      UK        42500
# 3     5PIB8XRHWF     Paris    NY   Japan        42768
# 4     SD7GTTO62M     Paris    CA     USA        78487
# ...          ...       ...   ...     ...          ...
# 9995  OHPXAYLQ88    London    FL  France         4409
# 9996  TWZ3YNJULK     Tokyo    NY   Japan        11160
# 9997  CP2QA99ZJI     Paris    FL      UK        34296
# 9998  DIPPS1HVI1    London    TX      UK        38620
# 9999  HCXXYDQ2SF  New York    CA  France        58542
#
# [10000 rows x 12 columns]

# %%
df['Salary'].plot(kind='hist')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: ylabel='Frequency'>

# %%
df['Salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Salary'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.groupby('Department')['Salary'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
df.groupby('Department')['Salary'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='Salary'>

# %%
import pandas as pd 

df=pd.read_csv('employees.csv')
df 

df['Salary'].plot(kind='hist').get_figure().savefig('histogram.png')
df['Salary'].plot(kind='box').get_figure().savefig('boxplot.png')
df['Salary'].plot(kind='bar').get_figure().savefig('bar_chart.png')

df.groupby('Department')['Salary'].sum().plot(kind='bar').get_figure().savefig('grouped_bar_chart.png')
df.groupby('Department')['Salary'].sum().plot(kind='pie').get_figure().savefig('grouped_pie_chart.png')

# %%
import seaborn as sns

sns.heatmap(df[['Salary', 'Age']].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df[['Salary', 'Age']].corr(),annot=True).get_figure().savefig('heatmap.png')
